# %% [markdown]
# # Elevazione al quadrato
#
# in questo piccolo programma , viene calcalata **l'elevazione al quadrato** di un *numero*.

# %%
a = 5
al_quadrato = a**2

print(al_quadrato)
# Out:
# 25

# %% [markdown]
# **FINE** *programma*
